# %%
import numpy as np

# 원본 행렬 R 생성, 분해 행렬 P와 Q 초기화, 잠재 요인 차원 K는 3으로 설정.
R = np.array([[4, np.NaN, np.NaN, 2, np.NaN],
             [np.NaN, 5, np.NaN, 3, 1],
             [np.NaN, np.NaN, 3, 4, 4],
             [5, 2, 1, 2, np.NaN]])
num_users, num_items = R.shape
K=3

# P와 Q 행렬의 크기를 지정하고 정규 분포를 가진 임의의 값으로 입력합니다.
np.random.seed(1)
P = np.random.normal(scale=1./K, size=(num_users, K))
Q = np.random.normal(scale=1./K, size=(num_items, K))

# %%
from sklearn.metrics import mean_squared_error

def get_rmse(R, P, Q, non_zeros):
    error = 0
    # 두 개의 분해된 행렬 P와 Q.T의 내적으로 예측 R 행렬 생성
    full_pred_matrix = np.dot(P, Q.T)
    
    # 실제 R 행렬에서 널이 아닌 값의 위치 인덱스 추출해 실제 R 행렬과 예측 행렬의 RMSE 추출
    x_non_zero_ind = [non_zero[0] for non_zero in non_zeros]
    y_non_zero_ind = [non_zero[1] for non_zero in non_zeros]
    R_non_zeros = R[x_non_zero_ind, y_non_zero_ind]
    full_pred_matrix_non_zeros = full_pred_matrix[x_non_zero_ind, y_non_zero_ind]
    mse = mean_squared_error(R_non_zeros, full_pred_matrix_non_zeros)
    rmse = np.sqrt(mse)
    
    return rmse

# %%
# R > 0인 행 위치, 열 위치, 값을 non_zeros 리스트에 저장.
non_zeros = [ (i, j, R[i, j]) for i in range(num_users) for j in range(num_items) if R[i, j] > 0 ]

steps=1000
learning_rate=0.01
r_lambda=0.01

# SGD 기법으로 P와 Q 매트릭스를 계속 업데이트.
for step in range(steps):
    for i, j, r in non_zeros:
        # 실제 값과 예측 값의 차이인 오류 값 구함
        eij = r - np.dot(P[i, :], Q[j, :].T)
        # Regularization을 반영한 SGD 업데이트 공식 적용
        P[i, :] = P[i, :] + learning_rate*(eij * Q[j, :] - r_lambda*P[i, :])
        Q[j, :] = Q[j, :] + learning_rate*(eij * P[i, :] - r_lambda*Q[j, :])
        
        rmse = get_rmse(R, P, Q, non_zeros)
        if (step % 50) == 0 :
            print("### iteration step : ", step, "rmse : ", rmse)
# Out:
# ### iteration step :  0 rmse :  3.259459570920174
# ### iteration step :  0 rmse :  3.2585295271131973
# ### iteration step :  0 rmse :  3.2521099280637533
# ### iteration step :  0 rmse :  3.250301384821969
# ### iteration step :  0 rmse :  3.2504784118719807
# ### iteration step :  0 rmse :  3.2492149633392726
# ### iteration step :  0 rmse :  3.247385782225293
# ### iteration step :  0 rmse :  3.245556255980146
# ### iteration step :  0 rmse :  3.2401598629557324
# ### iteration step :  0 rmse :  3.2382931118523164
# ### iteration step :  0 rmse :  3.238413055138202
# ### iteration step :  0 rmse :  3.2370465747107744
# ### iteration step :  50 rmse :  0.5015004152105822
# ### iteration step :  50 rmse :  0.5013163339724306
# ### iteration step :  50 rmse :  0.5001971542619057
# ### iteration step :  50 rmse :  0.5000256311100154
# ### iteration step :  50 rmse :  0.5001282058216056
# ### iteration step :  50 rmse :  0.49949286286296574
# ### iteration step :  50 rmse :  0.4995902704360359
# ### iteration step :  50 rmse :  0.4991087164759484
# ### iteration step :  50 rmse :  0.49119062964752225
# ### iteration step :  50 rmse :  0.4902602272231556
# ### iteration step :  50 rmse :  0.48988331893036235
# ### iteration step :  50 rmse :  0.48884683353843905
# ### iteration step :  100 rmse :  0.16564042476989244
# ### iteration step :  100 rmse :  0.16537300603325766
# ### iteration step :  100 rmse :  0.16531818830007147
# ### iteration step :  100 rmse :  0.1648757690352492
# ### iteration step :  100 rmse :  0.16489650522509935
# ### iteration step :  100 rmse :  0.1648654241400033
# ### iteration step :  100 rmse :  0.16444864298141992
# ### iteration step :  100 rmse :  0.16449513044583444
# ### iteration step :  100 rmse :  0.16381593166875413
# ### iteration step :  100 rmse :  0.16369378971915738
# ### iteration step :  100 rmse :  0.1634549506271301
# ### iteration step :  100 rmse :  0.16295696042078667
# ### iteration step :  150 rmse :  0.08115662025806143
# ### iteration step :  150 rmse :  0.08115288660850654
# ### iteration step :  150 rmse :  0.08114452526534732
# ### iteration step :  150 rmse :  0.08086252251267527
# ### iteration step :  150 rmse :  0.0809010439908041
# ### iteration step :  150 rmse :  0.08093638992367704
# ### iteration step :  150 rmse :  0.08060622202805807
# ### iteration step :  150 rmse :  0.08064765606254354
# ### iteration step :  150 rmse :  0.08031619783924461
# ### iteration step :  150 rmse :  0.08032915042982565
# ### iteration step :  150 rmse :  0.08032466606941722
# ### iteration step :  150 rmse :  0.08020066824119745
# ### iteration step :  200 rmse :  0.047804551705241345
# ### iteration step :  200 rmse :  0.0478934785319002
# ### iteration step :  200 rmse :  0.04788137350159899
# ### iteration step :  200 rmse :  0.04766090471286391
# ### iteration step :  200 rmse :  0.047713713065170436
# ### iteration step :  200 rmse :  0.04777214938408417
# ### iteration step :  200 rmse :  0.047485758200688455
# ### iteration step :  200 rmse :  0.04751029757527921
# ### iteration step :  200 rmse :  0.04726616735326997
# ### iteration step :  200 rmse :  0.04729144340016958
# ### iteration step :  200 rmse :  0.04729442162018789
# ### iteration step :  200 rmse :  0.04739718367306318
# ### iteration step :  250 rmse :  0.03232722891322595
# ### iteration step :  250 rmse :  0.032453670612177035
# ### iteration step :  250 rmse :  0.03242128301518027
# ### iteration step :  250 rmse :  0.03223884706369804
# ### iteration step :  250 rmse :  0.03230743667003826
# ### iteration step :  250 rmse :  0.032371568445615305
# ### iteration step :  250 rmse :  0.03210472931848245
# ### iteration step :  250 rmse :  0.03211424471496362
# ### iteration step :  250 rmse :  0.03188484662194649
# ### iteration step :  250 rmse :  0.031924684562491916
# ### iteration step :  250 rmse :  0.03192613777182942
# ### iteration step :  250 rmse :  0.03213581083091943
# ### iteration step :  300 rmse :  0.024671619524324746
# ### iteration step :  300 rmse :  0.02481099505271553
# ### iteration step :  300 rmse :  0.02475196204361298
# ### iteration step :  300 rmse :  0.024597938463634755
# ### iteration step :  300 rmse :  0.02468141167546361
# ### iteration step :  300 rmse :  0.024741120114817307
# ### iteration step :  300 rmse :  0.02448840789750861
# ### iteration step :  300 rmse :  0.02448741185346759
# ### iteration step :  300 rmse :  0.024244286675337814
# ### iteration step :  300 rmse :  0.024305677046079936
# ### iteration step :  300 rmse :  0.024322759711726483
# ### iteration step :  300 rmse :  0.024577612755883046
# ### iteration step :  350 rmse :  0.020888783335950296
# ### iteration step :  350 rmse :  0.02102797381666542
# ### iteration step :  350 rmse :  0.020944540081270946
# ### iteration step :  350 rmse :  0.02081301322126551
# ### iteration step :  350 rmse :  0.02090766622499321
# ### iteration step :  350 rmse :  0.020957851458533502
# ### iteration step :  350 rmse :  0.020719858426921645
# ### iteration step :  350 rmse :  0.020712145095171823
# ### iteration step :  350 rmse :  0.02044886296703819
# ### iteration step :  350 rmse :  0.020531158631629878
# ### iteration step :  350 rmse :  0.02056837367763964
# ### iteration step :  350 rmse :  0.02083806542184041
# ### iteration step :  400 rmse :  0.01903503066886171
# ### iteration step :  400 rmse :  0.01916804303441504
# ### iteration step :  400 rmse :  0.019066644511679328
# ### iteration step :  400 rmse :  0.01895198329603423
# ### iteration step :  400 rmse :  0.019053601493827812
# ### iteration step :  400 rmse :  0.0190938236604138
# ### iteration step :  400 rmse :  0.018870189821573725
# ### iteration step :  400 rmse :  0.01885841497747801
# ### iteration step :  400 rmse :  0.01857835774377045
# ### iteration step :  400 rmse :  0.01867634393094568
# ### iteration step :  400 rmse :  0.01872977547551532
# ### iteration step :  400 rmse :  0.01900125090799804
# ### iteration step :  450 rmse :  0.01811319096270037
# ### iteration step :  450 rmse :  0.018238574915239707
# ### iteration step :  450 rmse :  0.018125393615852935
# ### iteration step :  450 rmse :  0.018022462454374163
# ### iteration step :  450 rmse :  0.018128031551534855
# ### iteration step :  450 rmse :  0.0181602243446237
# ### iteration step :  450 rmse :  0.017948618021303635
# ### iteration step :  450 rmse :  0.017934385139530083
# ### iteration step :  450 rmse :  0.017642571025706308
# ### iteration step :  450 rmse :  0.017750894020664355
# ### iteration step :  450 rmse :  0.017815198990271786
# ### iteration step :  450 rmse :  0.01808455770215301
# ### iteration step :  500 rmse :  0.01763631955626561
# ### iteration step :  500 rmse :  0.017754661260246416
# ### iteration step :  500 rmse :  0.01763405236901517
# ### iteration step :  500 rmse :  0.017538937931404944
# ### iteration step :  500 rmse :  0.017646733371423824
# ### iteration step :  500 rmse :  0.01767319298303841
# ### iteration step :  500 rmse :  0.017470717109102873
# ### iteration step :  500 rmse :  0.017454912407316777
# ### iteration step :  500 rmse :  0.017155165848821038
# ### iteration step :  500 rmse :  0.017269996596103503
# ### iteration step :  500 rmse :  0.017341119844339517
# ### iteration step :  500 rmse :  0.017608110115141747
# ### iteration step :  550 rmse :  0.017374724403030423
# ### iteration step :  550 rmse :  0.017487167760427944
# ### iteration step :  550 rmse :  0.017361838367915185
# ### iteration step :  550 rmse :  0.017271909302726866
# ### iteration step :  550 rmse :  0.0173810267111362
# ### iteration step :  550 rmse :  0.01740360027341211
# ### iteration step :  550 rmse :  0.01720775630834823
# ### iteration step :  550 rmse :  0.017190863121329506
# ### iteration step :  550 rmse :  0.016885670784227133
# ### iteration step :  550 rmse :  0.017004620241107472
# ### iteration step :  550 rmse :  0.017079978867646776
# ### iteration step :  550 rmse :  0.017345264338097074
# ### iteration step :  600 rmse :  0.01721979991862263
# ### iteration step :  600 rmse :  0.017327458373951846
# ### iteration step :  600 rmse :  0.01719901119270623
# ### iteration step :  600 rmse :  0.01711261726045146
# ### iteration step :  600 rmse :  0.017222589794479562
# ### iteration step :  600 rmse :  0.017242567213021382
# ### iteration step :  600 rmse :  0.0170514935455242
# ### iteration step :  600 rmse :  0.017033785862638227
# ### iteration step :  600 rmse :  0.01672472051375352
# ### iteration step :  600 rmse :  0.016846371296963945
# ### iteration step :  600 rmse :  0.016924418318819547
# ### iteration step :  600 rmse :  0.0171886279831836
# ### iteration step :  650 rmse :  0.017118869568523487
# ### iteration step :  650 rmse :  0.017222666785560933
# ### iteration step :  650 rmse :  0.017092034436421932
# ### iteration step :  650 rmse :  0.017008178904430935
# ### iteration step :  650 rmse :  0.017118761890431704
# ### iteration step :  650 rmse :  0.017136990840914496
# ### iteration step :  650 rmse :  0.016949381919718363
# ### iteration step :  650 rmse :  0.016931025126865076
# ### iteration step :  650 rmse :  0.0166191002533498
# ### iteration step :  650 rmse :  0.01674262457843312
# ### iteration step :  650 rmse :  0.016822451331407064
# ### iteration step :  650 rmse :  0.017085979050797392
# ### iteration step :  700 rmse :  0.017045566217993385
# ### iteration step :  700 rmse :  0.01714623006482441
# ### iteration step :  700 rmse :  0.017013952393410987
# ### iteration step :  700 rmse :  0.016932045800614234
# ### iteration step :  700 rmse :  0.017043107771739983
# ### iteration step :  700 rmse :  0.017060131494898805
# ### iteration step :  700 rmse :  0.01687508971640985
# ### iteration step :  700 rmse :  0.016856190590676622
# ### iteration step :  700 rmse :  0.016542081465042584
# ### iteration step :  700 rmse :  0.016666997075212412
# ### iteration step :  700 rmse :  0.016748071893810435
# ### iteration step :  700 rmse :  0.017011105345954212
# ### iteration step :  750 rmse :  0.016986339809632607
# ### iteration step :  750 rmse :  0.017084436967500317
# ### iteration step :  750 rmse :  0.01695082628138874
# ### iteration step :  750 rmse :  0.01687052431794103
# ### iteration step :  750 rmse :  0.016981992777462186
# ### iteration step :  750 rmse :  0.016998157223925153
# ### iteration step :  750 rmse :  0.016815064431302935
# ### iteration step :  750 rmse :  0.01679569624436408
# ### iteration step :  750 rmse :  0.016479869527267463
# ### iteration step :  750 rmse :  0.016605894622770893
# ### iteration step :  750 rmse :  0.016687905807086255
# ### iteration step :  750 rmse :  0.01695049632118325
# ### iteration step :  800 rmse :  0.016934119095486123
# ### iteration step :  800 rmse :  0.017030092664032107
# ### iteration step :  800 rmse :  0.016895330096365964
# ### iteration step :  800 rmse :  0.01681643299125965
# ### iteration step :  800 rmse :  0.01692826691339896
# ### iteration step :  800 rmse :  0.01694379364389866
# ### iteration step :  800 rmse :  0.01676221822895212
# ### iteration step :  800 rmse :  0.016742433865408562
# ### iteration step :  800 rmse :  0.016425223785991625
# ### iteration step :  800 rmse :  0.016552192555841654
# ### iteration step :  800 rmse :  0.016634956416681296
# ### iteration step :  800 rmse :  0.016897077307735806
# ### iteration step :  850 rmse :  0.016885209229715058
# ### iteration step :  850 rmse :  0.016979409506174468
# ### iteration step :  850 rmse :  0.01684360090717783
# ### iteration step :  850 rmse :  0.016765992807521803
# ### iteration step :  850 rmse :  0.016878168291140607
# ### iteration step :  850 rmse :  0.016893201338724927
# ### iteration step :  850 rmse :  0.016712835690061715
# ### iteration step :  850 rmse :  0.016692674864229543
# ### iteration step :  850 rmse :  0.01637432897820257
# ### iteration step :  850 rmse :  0.016502142600004512
# ### iteration step :  850 rmse :  0.01658554989326126
# ### iteration step :  850 rmse :  0.016847135572712814
# ### iteration step :  900 rmse :  0.01683771176354243
# ### iteration step :  900 rmse :  0.016930419312574652
# ### iteration step :  900 rmse :  0.016793627638952112
# ### iteration step :  900 rmse :  0.01671724068566275
# ### iteration step :  900 rmse :  0.016829743262746194
# ### iteration step :  900 rmse :  0.01684437846757829
# ### iteration step :  900 rmse :  0.016664998056376078
# ### iteration step :  900 rmse :  0.016644491504265772
# ### iteration step :  900 rmse :  0.016325198895230597
# ### iteration step :  900 rmse :  0.01645379708155892
# ### iteration step :  900 rmse :  0.016537781778027408
# ### iteration step :  900 rmse :  0.016798751422296254
# ### iteration step :  950 rmse :  0.01679069355652947
# ### iteration step :  950 rmse :  0.016882136002329285
# ### iteration step :  950 rmse :  0.016744400074734322
# ### iteration step :  950 rmse :  0.016669193347642552
# ### iteration step :  950 rmse :  0.016782013769472644
# ### iteration step :  950 rmse :  0.0167963169196565
# ### iteration step :  950 rmse :  0.016617753766132667
# ### iteration step :  950 rmse :  0.01659692581436569
# ### iteration step :  950 rmse :  0.01627683492686904
# ### iteration step :  950 rmse :  0.01640617938243638
# ### iteration step :  950 rmse :  0.016490700427972224
# ### iteration step :  950 rmse :  0.01675097130379906

# %%
pred_matrix = np.dot(P, Q.T)
print('예측 행렬:\n', np.round(pred_matrix, 3))
# Out:
# 예측 행렬:
#  [[3.99  0.783 1.341 2.003 1.729]
#  [6.702 4.978 0.953 2.98  1.003]
#  [6.933 0.42  2.987 3.976 3.986]
#  [4.968 2.005 1.007 2.018 1.163]]
